# %% [markdown]
# # Seaborn

# %% [markdown]
# ##  - data visualization library for statistical graphics

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (4.28.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\welcome\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
df= sns.load_dataset('planets')
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df = sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
#using matplotlib
plt.scatter(df.year,df.passengers)
plt.show()

# %%
#using seaborn library
plt.scatter(df.year,df.passengers)
sns.set()
#plt.show()

# %%
#Set style
plt.scatter(df.year,df.passengers)
#darkgrid,whitegrid, dark,white,ticks 
sns.set_style("whitegrid")

plt.show()

# %%
plt.scatter(df.year,df.passengers)
#darkgrid,whitegrid, dark,white,ticks 
sns.set_style("ticks")
#To remove the top and right axis spines 
sns.despine()
plt.show()

# %%
#List out the axes_style
param = sns.axes_style()
param
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': False,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
#Set Context style: Paper,Notebook,Talk,Poster
plt.scatter(df.year,df.passengers)
#darkgrid,whitegrid, dark,white,ticks 
sns.set_style("dark")
sns.set_context("notebook")
plt.show()

# %%
#Seaborn Color Palette
#sns.palplot(sns.color_palette("deep", 10))
sns.palplot(sns.color_palette("PiYG", 10))

# %% [markdown]
# # Plotting with the relplot function

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x='total_bill',y='tip')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='day')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='sex')

# %%
sns.relplot(data=tips,x='total_bill',y='tip',hue='sex',col='day',col_wrap=2)

# %% [markdown]
# # Histogram -data distribution by forming bins

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Kernel Density Estimate - visualizing the Probability Density of the continuous or non-parametric data variables

# %%
sns.distplot(df['petal_length'],kde = False)
# Out:
# C:\Users\Welcome\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal_length'>

# %% [markdown]
# # Bar Plot

# %%
# load dataset
titanic = sns.load_dataset('titanic')
sns.set_context('paper')
# create plot
sns.barplot(x = 'embark_town', y = 'age', data = titanic,  palette = 'PuRd',
           ci=None
            )
plt.show()

# %%
sns.barplot(x = 'sex', y = 'survived', hue = 'class', data = titanic,palette = 'hls',
            order = ['male', 'female'],
            capsize = 0.15,
            saturation = 8,
            errcolor = 'gray', errwidth = 2,      
            ci = 'sd')
plt.legend()
plt.show()

# %% [markdown]
# #     Count plot

# %% [markdown]
# ## histogram across a categorical variable

# %%
sns.countplot(x = 'class', hue = 'who', data = titanic, palette ='magma')
plt.title('Survivors')
plt.show()

# %% [markdown]
# # Point Plot

# %%
data = sns.load_dataset("tips") 
sns.pointplot(x="day", y="tip", data=data)
plt.show()

# %% [markdown]
# # Joint Plot

# %%
tips=sns.load_dataset('tips')
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg') 
plt.show()

# %% [markdown]
# # Regplot
#
# ## visualize the linear relationship as determined through regression

# %%
ax = sns.regplot(x="total_bill", y="tip", data=tips)

# %%
#ci=None to remove the highlight in the line
ax = sns.regplot(x="total_bill", y="tip", data=tips,ci=None)

# %% [markdown]
# # Box Plot
# ## depicting groups of numerical data through the quartiles
#
# - Minimum -bottom black horizontal line of the box plot
# - First Quartile or 25% -first black horizontal line of the rectangle shape of the box plot
# - Median (Second Quartile) or 50% - second black horizontal line of the rectangle shape of the box plot
# - Third Quartile or 75% - third black horizontal line of rectangle shape
# - Maximum - top black horizontal line of the rectangle shape
# - outlier data - small diamond shape of the box plot

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Violin Plot
# ##  summarize numeric data over a set of categories

# %%
ax = sns.violinplot(x=tips["total_bill"])

# %%
sns.violinplot(x="day", y="total_bill", hue="smoker",
                    data=tips, palette="deep")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Heatmap
# ##  two-dimensional graphical representation of data where the individual values that are contained in a matrix are represented as colours.

# %%
flights=sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
print(flights)
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
sns.heatmap(flights,linewidths=.5,cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
flights=sns.load_dataset("flights")
corr=flights.corr()
print(corr)
sns.heatmap(corr,annot=True,linewidths=.5,cmap="YlGnBu")
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000
# <AxesSubplot:>

# %% [markdown]
# # Cluster map
# ## plots a matrix dataset as a hierarchically-clustered heatmap

# %%
flights=sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
sns.clustermap(flights,linewidths=.5,cmap="coolwarm")

# %% [markdown]
# # Facetgrid
# ## matrix of panels defined by row and column by dividing the variables.

# %%
tips = sns.load_dataset("tips")
g = sns.FacetGrid(tips, col="time")
g.map(sns.scatterplot, "total_bill", "tip")

# %% [markdown]
# # Pair Plot
# ## creates a grid of Axes of numeric variable in data

# %%
df = sns.load_dataset('iris')
sns.set_style("ticks")
sns.pairplot(df,hue = 'species',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()
